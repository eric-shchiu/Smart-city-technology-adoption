# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Data

# %%
transit_survey = pd.read_csv('Data/transit_survey.csv')
transit_survey.head()
# Out:
#    NTDID                                     AgencyName  \
# 0  90003  San Francisco Bay Area Rapid Transit District
# 1  90004                 Golden Empire Transit District
# 2  90006       Santa Cruz Metropolitan Transit District
# 3  90007                                        Modesto
# 4  90008                                   Santa Monica
#
#                      OrgType        reptype              id  survey_response  \
# 0  Independent Public Agency  Full Reporter  Principal City                0
# 1  Independent Public Agency  Full Reporter  Principal City                0
# 2  Independent Public Agency  Full Reporter  Principal City                0
# 3           Local Government  Full Reporter  Principal City                0
# 4           Local Government  Full Reporter  Principal City                1
#
#          pop   mile   VOMS       revenue          City       County  \
# 0  1834004.0  113.0  566.0  1.267969e+09       Oakland      Alameda
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Meta data

# %%
ax = sns.countplot(data = transit_survey, x = 'id')

for container in ax.containers:
    ax.bar_label(container)
    
plt.ylim(0,80)
plt.title('Type of cities', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Type of cities')

# %%
ax = sns.countplot(data = transit_survey, x = 'OrgType')

for container in ax.containers:
    ax.bar_label(container)

plt.ylim(0,130)
plt.title('Type of organization', fontsize = 15)
plt.xticks(rotation = 45, horizontalalignment='right')
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Independent Public Agency'),
#   Text(1, 0, 'Local Government'),
#   Text(2, 0, 'Other'),
#   Text(3, 0, 'MPO/RTPA')])

# %%
sns.boxplot(data = transit_survey, x = 'pop')
plt.title('Population', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Population')

# %%
sns.boxplot(data = transit_survey, x = 'revenue')
plt.title('Revenue', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Revenue')

# %%
rev_per_capita = transit_survey['revenue']/transit_survey['pop']

sns.histplot(data = rev_per_capita)
plt.title('Revenue per capita', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Revenue per capita')

# %% [markdown]
# ## Angencies responded to survey

# %%
responded = transit_survey[transit_survey['survey_response'] == 1]
responded
# Out:
#      NTDID                                         AgencyName  \
# 4    90008                                       Santa Monica
# 8    90013        Santa Clara Valley Transportation Authority
# 12   90017                                         Santa Rosa
# 14   90020        Santa Barbara Metropolitan Transit District
# 16   90023                                 Long Beach Transit
# ..     ...                                                ...
# 181    NaN  Santa Barbara County Association of Government...
# 182    NaN         Fresno Council of Governments (Fresno COG)
# 189    NaN                                          Riverside
# 204    NaN              Tulare County Regional Transit Agency
# 220    NaN            Tehama County Transportation Commission
#
#                        OrgType        reptype              id  \
# 4             Local Government  Full Reporter  Principal City
# 8    Independent Public Agency  Full Reporter  Principal City
# ...

# %%
ax = sns.countplot(data = responded, x = 'id')

for container in ax.containers:
    ax.bar_label(container)
    
plt.ylim(0,80)
plt.title('Type of cities', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Type of cities')

# %%
ax = sns.countplot(data = responded, x = 'OrgType')

for container in ax.containers:
    ax.bar_label(container)

plt.ylim(0,130)
plt.title('Type of organization', fontsize = 15)
plt.xticks(rotation = 45, horizontalalignment='right')
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Local Government'),
#   Text(1, 0, 'Independent Public Agency'),
#   Text(2, 0, 'Other'),
#   Text(3, 0, 'MPO/RTPA')])

# %%
sns.boxplot(data = responded, x = 'pop')
plt.title('Population', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Population')

# %%
sns.boxplot(data = responded, x = 'revenue')
plt.title('Revenue', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Revenue')

# %%
rev_per_capita_responded = responded['revenue']/responded['pop']

sns.histplot(data = rev_per_capita_responded)
plt.title('Revenue per capita', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Revenue per capita')

# %%
transit_survey['id'].value_counts().index.tolist()
# Out:
# ['Principal City', 'Suburban City', 'Small Rural City']

# %% [markdown]
# ## Compare metadata and reponded data

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 15))

fig.suptitle('Type of cities', fontsize = 20, ha='center',va='bottom')
plt.subplots_adjust(top=1.5)

plt.subplot(121)
plt.pie(transit_survey['id'].value_counts(), labels = transit_survey['id'].value_counts().index.tolist(), autopct='%.0f%%')

plt.subplot(122)
plt.pie(responded['id'].value_counts(), labels = responded['id'].value_counts().index.tolist(), autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x289217b80>,
# ...
#  [Text(-0.26324721533219847, 1.0680360029605012, 'Principal City'),
#   Text(-0.3272533894949263, -1.050192943731809, 'Small Rural City'),
#   Text(0.9413593913346187, -0.569071609154873, 'Suburban City')],
#  [Text(-0.14358939018119915, 0.5825650925239096, '58%'),
#   Text(-0.1785018488154143, -0.5728325147628047, '25%'),
#   Text(0.5134687589097919, -0.31040269590265795, '17%')])

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 15))

fig.suptitle('Type of organization', fontsize = 20, ha='center',va='bottom')
plt.subplots_adjust(top=1.5)

plt.subplot(121)
plt.pie(transit_survey['OrgType'].value_counts(), labels = transit_survey['OrgType'].value_counts().index.tolist(), autopct='%.0f%%')

plt.subplot(122)
plt.pie(responded['OrgType'].value_counts(), labels = responded['OrgType'].value_counts().index.tolist(), autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x289362a30>,
# ...
#  [Text(0.166570601230037, 1.0873151497178102, 'Independent Public Agency'),
#   Text(-0.7578637048927315, -0.7972719766844077, 'Local Government'),
#   Text(0.8346338159412021, -0.7165098696371375, 'MPO/RTPA'),
#   Text(1.0943562352286353, -0.11128535580303443, 'Other')],
#  [Text(0.09085669158002017, 0.5930809907551692, '45%'),
#   Text(-0.4133802026687626, -0.43487562364604054, '35%'),
#   Text(0.4552548086952011, -0.3908235652566204, '16%'),
#   Text(0.5969215828519828, -0.060701103165291495, '3%')])

# %%
# In log scale
pop = pd.concat([transit_survey['pop'].reset_index(drop = True).rename('pop_meta'),responded['pop'].reset_index(drop = True).rename('pop_respond')], axis = 1)

plt.figure(figsize = (10,10))
sns.boxplot(data = pop)
plt.title('Population', fontsize = 15)
plt.yscale('log')

# %% [markdown]
# Comment: How to better compare this?

# %%
# In log scale
pop = pd.concat([transit_survey['revenue'].reset_index(drop = True).rename('revenue_meta'),responded['revenue'].reset_index(drop = True).rename('revenue_respond')], axis = 1)

plt.figure(figsize = (10,10))
sns.boxplot(data = pop)
plt.title('Revenue', fontsize = 15)
plt.yscale('log')

# %%
rev_per_capita_combine = pd.concat([rev_per_capita.reset_index(drop = True).rename('rev_per_capita_meta'), rev_per_capita_responded.reset_index(drop = True).rename('rev_per_capita_respond')], axis = 1)
rev_per_capita_combine.head()
# Out:
#    rev_per_capita_meta  rev_per_capita_respond
# 0           691.366480              102.996924
# 1            65.002556              357.533752
# 2           178.785632               70.663144
# 3            83.894183              142.673518
# 4           102.996924              138.296293

# %%
plt.figure(figsize=(15,10))
sns.histplot(data = rev_per_capita_combine, stat='percent', common_norm = False, kde = True)
# Out:
# <AxesSubplot:ylabel='Percent'>

# %%
sns.barplot(data = rev_per_capita_combine)
plt.title('Revenue per capita', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Revenue per capita')
